# %%
import json
import requests
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('ba_fr.xlsx')
assetturnover = df['assetTurnover']

import pandas as pd
s = pd.Series([1, 3, 2])
line = s.plot.line()
